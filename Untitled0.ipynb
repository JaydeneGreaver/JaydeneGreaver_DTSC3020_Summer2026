# %% [markdown]
# <a href="https://colab.research.google.com/github/JaydeneGreaver/JaydeneGreaver_DTSC3020_Summer2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('Hello, DTSC 3020')
print ('Welcome to Python programming')
# Out:
# Hello, DTSC 3020
# Welcome to Python programming
