# %% [markdown]
# <a href="https://colab.research.google.com/github/JaydeneGreaver/JaydeneGreaver_DTSC3020_Summer2026/blob/main/Jaydene_Greaver_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Respondus LockDown Browser Practice Notebook
#
# This notebook is only for testing whether you can:
#
# 1. Open a Google Colab notebook during the practice quiz.
# 2. Save a copy to your Google Drive.
# 3. Edit and run notebook cells.
# 4. Save the completed notebook to GitHub.
# 5. Submit the GitHub link in Canvas.
#
# **This activity is not a coding assessment.**

# %% [markdown]
# ## Step 1 — Save a copy to Google Drive
#
# In Google Colab, select:
#
# **File → Save a copy in Drive**
#
# Rename the copied notebook using this format:
#
# `FirstName_LastName_Practice.ipynb`

# %% [markdown]
# ## Step 2 — Enter your information
#
# Replace the example text below with your own information, and then run the cell.

# %%
# Replace the example information with your own information
student_name = "Jaydene Greaver"


print("Student Name:", student_name)
# Out:
# Student Name: Jaydene Greaver

# %% [markdown]
# ## Step 3 — Complete a simple test
#
# Replace the value of `favorite_number` with any number, and then run the cell.

# %%
favorite_number = 7

result = favorite_number * 2
print("Your favorite number is:", favorite_number)
print("Your favorite number multiplied by 2 is:", result)
# Out:
# Your favorite number is: 7
# Your favorite number multiplied by 2 is: 14

# %% [markdown]
# ## Step 4 — Confirm that the notebook works
#
# Run the following cell. You should see a confirmation message.

# %%
if student_name == "Jaydene Greaver" or student_id == "11976910":
    print("Please return to Step 2 and enter your information.")
else:
    print("Practice notebook completed successfully!")
    print("You can now save this notebook to GitHub.")
# Out:
# Please return to Step 2 and enter your information.

# %% [markdown]
# ## Step 5 — Save the notebook to GitHub
#
# In Google Colab, select:
#
# **File → Save a copy in GitHub**
#
# Then:
#
# 1. Select your GitHub repository.
# 2. Keep the notebook filename in the required format.
# 3. Add a commit message such as `Complete Respondus practice notebook`.
# 4. Click **OK**.
# 5. Open the notebook on GitHub.
# 6. Copy the GitHub URL.
# 7. Paste that URL into the answer box in Canvas.
#
# Your submitted link should begin with:
#
# `https://github.com/`

# %% [markdown]
# ## Technical issue note
#
# If you cannot open Colab, save to Google Drive, run the cells, access GitHub, or submit the link in Canvas, take a picture or screenshot of the error and contact the course instructional team before the final exam.
